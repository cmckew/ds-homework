# %% [markdown]
# # Project 4
#
# In this project, you will summarize and present your analysis from Projects 1-3.

# %% [markdown]
# ### Intro: Write a problem Statement/ Specific Aim for this project

# %% [markdown]
# Answer: It is difficult to determine which admissions statistic has the most weight in increasing the probability of addmittance to graduate school.  We are looking to determine how the probability of admission will increase with the combination of GPA, GRE, and rank of undergraduate program.

# %% [markdown]
# ### Dataset:  Write up a description of your data and any cleaning that was completed

# %% [markdown]
# Answer: The data contained 3 variables that would be used to predict the likelyhood of admittance.  There was a need to clean the data which pertained to removing null data points in our data set.

# %% [markdown]
# ### Demo: Provide a table that explains the data by admission status

# %% [markdown]
# Mean (STD) or counts by admission status for each variable
#
# | Not Admitted | Admitted
# ---| ---|---
# GRE | 573.579336 | 618.571429
# GPA | 3.347159 | 3.489206
# prestige_1.0 | 28 | 33
# prestige_2.0 | 95 | 53
# prestige_3.0 | 93 | 28
# prestige_4.0 | 55 | 12

# %% [markdown]
# ### Methods: Write up the methods used in your analysis

# %% [markdown]
# Answer: In the analysis, a logistic regression was utilized to generate the odds and probability of being admitted.  Dummy variables were added for the predictor 'prestige' to train the model and calculate the odds ratios.  Furthermore, a cartesian function was utilized to display how the predicted probability increases or decreases across the different variables.

# %% [markdown]
# ### Results: Write up your results

# %% [markdown]
# Answer: The model showed that the probability of admission increase in conjuction with GRE and GPA performance (higher score leads to higher probability of addmittance).  It also showed a large gap in admission probability across the range of school prestige (1-4).

# %% [markdown]
# ### Visuals: Provide a table or visualization of these results

# %% [markdown]
# ![GPA_ADMIT.png](attachment:GPA_ADMIT.png)

# %% [markdown]
# ![GRE_ADMIT.png](attachment:GRE_ADMIT.png)

# %% [markdown]
# ### Discussion: Write up your discussion and future steps

# %% [markdown]
# Answer: The model showed a strong ability to predict admittance to a graduate program based on these three variables.  Furthermore, it also showed which predictor varibales seemed to carry the most influence in the decision if a candidate was to be admitted or not.  In future steps, it would be helpful to have a source regarding how undergradate rank is determined, as well as how highly regarded this certain graduate program might be.
